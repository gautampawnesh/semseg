# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
loc = "/Users/pawnesh/ws/thesis_exp_results/benchmark"

# %%
img = Image.open(f"{loc}/wilddash/wd0756_100000.png")

# %%
arr = np.array(img)

# %%
np.unique(arr)
# Out:
# array([ 0,  1,  7,  8, 11, 12, 13, 14, 17, 19, 20, 21, 22, 25, 26, 35, 36,
#        37], dtype=uint8)

# %%
proc_arr = np.where(arr == 25, 25, 0)

# %%
plt.imshow(proc_arr)

# %%
plt.imshow(arr)

# %%
img_test = Image.open(f"{loc}/wild_test/wilddash/wd0756_100000.png")

# %%
arr_test = np.array(img_test)

# %%
np.unique(arr_test)
# Out:
# array([ 0,  1,  7,  8, 11, 12, 13, 14, 17, 20, 21, 22, 23, 26, 27, 36, 37,
#        38], dtype=uint8)

# %%
plt.imshow(img_test)

# %%
proc_arr_test = np.where(arr_test == 26, 26, 0)

# %%
plt.imshow(proc_arr_test)
